# %% [markdown]
# # Python Basics Exercises

# %%
# Task 1: Print your name with your father's name and date of birth using escape sequences
name = "Muhammad Mateen Brohi"
father_name = "Ghulam Nabi"
dob = "25-11-2001"
print(f"My Name: {name}\nFather's Name: {father_name}\nDate of Birth: {dob}")

# Task 2: Write your small bio using variables and print it
bio_name = "Muhammad Mateen Brohi"
bio_age = 23
bio_hobby = "Reading"
print(f"My name is {bio_name}. I am {bio_age} years old. I love {bio_hobby}.")

# Task 3: Write a program using all Python operators
a, b = 10, 3
print("Arithmetic Operators:", a + b, a - b, a * b, a / b, a % b, a ** b, a // b)
print("Comparison Operators:", a == b, a != b, a > b, a < b, a >= b, a <= b)
print("Logical Operators:", a > 5 and b < 5, a > 5 or b > 5, not (a < 5))
print("Bitwise Operators:", a & b, a | b, a ^ b, ~a, a << 1, b >> 1)
print("Assignment Operators:")
a += b
print("a += b:", a)

# Task 4: Mention marks of three subjects and calculate percentage
english = 80
islamiat = 70
maths = 90
total_marks = 300
obtained_marks = english + islamiat + maths
percentage = (obtained_marks / total_marks) * 100
print(f"Percentage: {percentage:.2f}%")


# Task 5: Calculate bonus for employees
salary = int(input("Enter salary: "))
years_of_service = int(input("Enter years of service: "))
if years_of_service > 5:
    bonus = salary * 0.05
    print(f"Bonus: {bonus}")
else:
    print("No bonus")

# Task 6: Check voting eligibility
age = int(input("Enter your age: "))
print("Eligible for voting" if age > 17 else "Not eligible for voting")

# Task 7: Check even or odd
number = int(input("Enter a number: "))
print("Even" if number % 2 == 0 else "Odd")

# Task 8: Check divisibility by 7
number = int(input("Enter a number: "))
print("Divisible by 7" if number % 7 == 0 else "Not divisible by 7")

# Task 9: Check if number is multiple of 5
number = int(input("Enter a number: "))
print("Hello" if number % 5 == 0 else "Bye")

# Task 10: Display the last digit of a number
number = int(input("Enter a number: "))
print("Last digit:", number % 10)

# Task 11: Check if shape is square or rectangle
length = int(input("Enter length: "))
breadth = int(input("Enter breadth: "))
print("Square" if length == breadth else "Rectangle")

# Task 12: Find the greatest among two numbers
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
print("Greatest:", max(num1, num2))

# Task 13: Calculate cost with discount
quantity = int(input("Enter quantity: "))
cost = quantity * 100
if cost > 1000:
    cost -= cost * 0.1
print("Total cost:", cost)

# Task 14: Print grade based on marks
marks = int(input("Enter marks: "))
if marks < 25:
    grade = 'F'
elif marks < 45:
    grade = 'E'
elif marks < 50:
    grade = 'D'
elif marks < 60:
    grade = 'C'
elif marks < 80:
    grade = 'B'
else:
    grade = 'A'
print("Grade:", grade)

# Task 15: Check attendance for exam eligibility
classes_held = int(input("Enter number of classes held: "))
classes_attended = int(input("Enter number of classes attended: "))
attendance_percentage = (classes_attended / classes_held) * 100
print(f"Attendance: {attendance_percentage:.2f}%")
if attendance_percentage >= 75:
    print("Allowed to sit in exam")
else:
    medical_cause = input("Do you have a medical cause? (Y/N): ")
    print("Allowed to sit in exam" if medical_cause.lower() == 'y' else "Not allowed to sit in exam")

# Task 16: Check leap year
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap year")
else:
    print("Not a leap year")

# Task 17: Determine place of service
age = int(input("Enter age: "))
gender = input("Enter gender (M/F): ")
marital_status = input("Enter marital status (Y/N): ")
if gender == 'F':
    print("Urban areas only")
elif gender == 'M':
    if 20 <= age <= 40:
        print("Anywhere")
    elif 40 < age <= 60:
        print("Urban areas only")
    else:
        print("ERROR")
else:
    print("Invalid input")

# Task 18: Calculate electricity bill
units = int(input("Enter number of units: "))
if units <= 100:
    bill = 0
elif units <= 300:
    bill = (units - 100) * 5
else:
    bill = 200 * 5 + (units - 300) * 10
print("Electricity bill:", bill)

# Task 19: Determine oldest and youngest among three people
age1 = int(input("Enter age of first person: "))
age2 = int(input("Enter age of second person: "))
age3 = int(input("Enter age of third person: "))
print("Oldest:", max(age1, age2, age3))
print("Youngest:", min(age1, age2, age3))
# Out:
# My Name: Muhammad Mateen Brohi
# Father's Name: Ghulam Nabi
# Date of Birth: 25	1
# My name is Muhammad Mateen Brohi. I am 25 years old. I love Reading.
# Arithmetic Operators: 13 7 30 3.3333333333333335 1 1000 3
# Comparison Operators: False True True False True False
# Logical Operators: True True True
# Bitwise Operators: 2 11 9 -11 20 1
# Assignment Operators:
# a += b: 13
# Percentage: 80.00%
